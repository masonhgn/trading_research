# %%
from ib_async import *
util.startLoop()  # Required for notebooks

ib = IB()
ib.connect('127.0.0.1', 4001, clientId=2)
# Out:
# <IB connected to 127.0.0.1:4001 clientId=2>

# %%
ib.disconnect()
# Out:
# 'Disconnecting from 127.0.0.1:4001, 117 B sent in 8 messages, 15.5 kB received in 334 messages, session time 5.42 s.'

# %%
# Request historical data
contract = Forex('EURUSD')
bars = ib.reqHistoricalData(
    contract, endDateTime='', durationStr='30 D',
    barSizeSetting='1 hour', whatToShow='MIDPOINT', useRTH=True)

# Convert to pandas dataframe (pandas needs to be installed):
df = util.df(bars)
print(df.head())
# Out:
#                        date     open      high       low     close  volume  \
# 0 2025-06-30 17:15:00-04:00  1.17795  1.178400  1.177785  1.178210    -1.0
# 1 2025-06-30 18:00:00-04:00  1.17821  1.179120  1.177830  1.178580    -1.0
# 2 2025-06-30 19:00:00-04:00  1.17858  1.178765  1.178340  1.178650    -1.0
# 3 2025-06-30 20:00:00-04:00  1.17865  1.179790  1.178635  1.179760    -1.0
# 4 2025-06-30 21:00:00-04:00  1.17976  1.180795  1.177970  1.178045    -1.0
#
#    average  barCount
# 0     -1.0        -1
# 1     -1.0        -1
# 2     -1.0        -1
# 3     -1.0        -1
# 4     -1.0        -1

# %%
prices = df['close'].tolist()
print(len(prices))

import matplotlib.pyplot as plt

plt.plot(df['close'])
plt.show()
# Out:
# 705
